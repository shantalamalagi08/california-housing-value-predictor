# %% [markdown]
# #### Final Project

# %% [markdown]
# problem statement - predicting house price(califonia)
#
# <img src="https://www.appliedaicourse.com/blog/wp-content/uploads/2025/01/House-Price-Prediction-Using-Machine-Learning.png">

# %% [markdown]
# ## California House Price Prediction Project

# %% [markdown]
# ### Objective
# > The objective of this project is to build a multiple linear regression model that predicts the median house value in California districts based on various features like median income, housing median age, and average room counts etc..........
#
# >#### Machine Learning Pipeline
#
# * Data Collection and Import
# * Exploratory Data Analysis & Data Cleaning (Handling Nulls and Duplicates)
# * Feature Selection & Data Splitting
# * Feature Scaling (Standardization)
# * Model Building & Training
# * Model Evaluation

# %% [markdown]
# # Step 1: Data Collection and Import
# # Load the dataset from a URL or local file path

# %% [markdown]
# >> importing required libraries

# %%
import pandas as pd
import numpy as np

# %%
! python -m pip install --upgrade certifi
# Out:
# Requirement already satisfied: certifi in c:\users\lenovo\appdata\local\programs\python\python314\lib\site-packages (2026.7.22)
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
data_url = "housing.csv"
df = pd.read_csv(data_url)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  str
# dtypes: float64(9), str(1)
# memory usage: 1.6 MB

# %% [markdown]
# #### in feauture called "total_bedrooms " we have null values so we need fix it (by mean/median)

# %%
# Check for duplicate rows
duplicates = df.duplicated().sum()
print("Duplicate rows:", duplicates)
# Out:
# Duplicate rows: 0

# %%
df.shape
# Out:
# (20640, 10)

# %%
df["total_bedrooms"].median()
# Out:
# np.float64(435.0)

# %%
# Handle missing values: Fill missing 'total_bedrooms' with the median of that column
median_bedrooms = df["total_bedrooms"].median()
df["total_bedrooms"].fillna(median_bedrooms, inplace=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9580\1752893930.py:3: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["total_bedrooms"].fillna(median_bedrooms, inplace=True)
# 0         129.0
# 1        1106.0
# 2         190.0
# 3         235.0
# 4         280.0
#           ...
# 20635     374.0
# 20636     150.0
# 20637     485.0
# 20638     409.0
# 20639     616.0
# Name: total_bedrooms, Length: 20640, dtype: float64

# %%
df["total_bedrooms"].isnull().sum()
# Out:
# np.int64(207)

# %% [markdown]
# ### Enhancing the Model: One-Hot Encoding and Feature Engineering

# %%
# Reload the dataset to include 'ocean_proximity' for one-hot encoding
df = pd.read_csv(data_url)

# Handle missing 'total_bedrooms' again after reloading
median_bedrooms = df["total_bedrooms"].median()
df["total_bedrooms"] = df["total_bedrooms"].fillna(median_bedrooms)

# %% [markdown]
# #### One-Hot Encoding for 'ocean_proximity'

# %%
# Apply one-hot encoding to 'ocean_proximity'
df_encoded = pd.get_dummies(df, columns=['ocean_proximity'], drop_first=True)
df_encoded.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0
#
#    ocean_proximity_INLAND  ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 0                   False                   False                      True
# 1                   False                   False                      True
# 2                   False                   False                      True
# 3                   False                   False                      True
# 4                   False                   False                      True
#
#    ocean_proximity_NEAR OCEAN
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False

# %% [markdown]
# #### features engineering
# >creating new features(based on other features(columns,input,vectors))

# %%
### Done with data preparation
# Create new features
df_encoded['rooms_per_household'] = df_encoded['total_rooms'] / df_encoded['households']
df_encoded['bedrooms_per_room'] = df_encoded['total_bedrooms'] / df_encoded['total_rooms']
df_encoded['population_per_household'] = df_encoded['population'] / df_encoded['households']

df_encoded.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0
#
#    ocean_proximity_INLAND  ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 0                   False                   False                      True
# 1                   False                   False                      True
# 2                   False                   False                      True
# 3                   False                   False                      True
# 4                   False                   False                      True
#
#    ocean_proximity_NEAR OCEAN  rooms_per_household  bedrooms_per_room  \
# 0                       False             6.984127           0.146591
# 1                       False             6.238137           0.155797
# 2                       False             8.288136           0.129516
# 3                       False             5.817352           0.184458
# 4                       False             6.281853           0.172096
#
#    population_per_household
# 0                  2.555556
# 1                  2.109842
# 2                  2.802260
# 3                  2.547945
# 4                  2.181467

# %% [markdown]
# #### vertical split(i/p and o/p)

# %%
 X=df_encoded.drop(columns="median_house_value")#i/p dataset

# %%
X.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_INLAND', 'ocean_proximity_ISLAND',
#        'ocean_proximity_NEAR BAY', 'ocean_proximity_NEAR OCEAN',
#        'rooms_per_household', 'bedrooms_per_room', 'population_per_household'],
#       dtype='str')

# %%
Y=df_encoded["median_house_value"]#o/p dataset

# %% [markdown]
# #### horizontal spliting (train,test)

# %%
from sklearn.model_selection import train_test_split

# %%
# Split the data into training (80%) and testing (20%) sets
X_train_new, X_test_new, Y_train_new, Y_test_new = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

# %%
X_train_new
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
# ...          ...       ...                 ...          ...             ...
# 11284    -117.96     33.78                35.0       1330.0           201.0
# 11964    -117.43     34.02                33.0       3084.0           570.0
# 5390     -118.38     34.03                36.0       2101.0           569.0
# 860      -121.96     37.58                15.0       3575.0           597.0
# 15795    -122.42     37.77                52.0       4226.0          1315.0
#
#        population  households  median_income  ocean_proximity_INLAND  \
# 14196      2300.0       623.0         3.2596                   False
# 8267       1314.0       756.0         3.8125                   False
# 17445       915.0       336.0         4.1563                   False
# 14265      1418.0       355.0         1.9425                   False
# 2271        874.0       380.0         3.5542                    True
# ...           ...         ...            ...                     ...
# 11284       658.0       217.0         6.3700                   False
# 11964      1753.0       449.0         3.0500                    True
# 5390       1756.0       527.0         2.9344                   False
# 860        1777.0       559.0         5.7192                   False
# 15795      2619.0      1242.0         2.5755                   False
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 14196                   False                     False
# 8267                    False                     False
# 17445                   False                     False
# 14265                   False                     False
# 2271                    False                     False
# ...                       ...                       ...
# 11284                   False                     False
# 11964                   False                     False
# 5390                    False                     False
# 860                     False                     False
# 15795                   False                      True
#
#        ocean_proximity_NEAR OCEAN  rooms_per_household  bedrooms_per_room  \
# 14196                        True             5.017657           0.200576
# 8267                         True             4.473545           0.232703
# 17445                        True             5.645833           0.174486
# 14265                        True             4.002817           0.258269
# 2271                        False             6.268421           0.180940
# ...                           ...                  ...                ...
# 11284                       False             6.129032           0.151128
# 11964                       False             6.868597           0.184825
# 5390                        False             3.986717           0.270823
# 860                         False             6.395349           0.166993
# 15795                       False             3.402576           0.311169
#
#        population_per_household
# 14196                  3.691814
# 8267                   1.738095
# 17445                  2.723214
# 14265                  3.994366
# 2271                   2.300000
# ...                         ...
# 11284                  3.032258
# 11964                  3.904232
# 5390                   3.332068
# 860                    3.178891
# 15795                  2.108696
#
# [16512 rows x 15 columns]

# %% [markdown]
# ##### standardization

# %%
from sklearn.preprocessing import StandardScaler
# Initialize the StandardScaler
scaler_new = StandardScaler()

# Fit and transform the training features
X_train_scaled_new = scaler_new.fit_transform(X_train_new) ## mean and sd

# Transform the testing features using the training set scaler
X_test_scaled_new = scaler_new.transform(X_test_new) # mean and sd

# %%
#### use regression model

from sklearn.linear_model import LinearRegression

lr=LinearRegression

# %%
lr.fit(X_train_scaled_new,y_train_new)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 lr.fit(X_train_scaled_new,Y_train_new)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\base.py:1393, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1388 partial_fit_and_fitted = (
#    1389     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1390 )
#    1392 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
#    1403     return fit_method(estimator, *args, **kwargs)
#
# AttributeError: 'numpy.ndarray' object has no attribute '_validate_params'
